# %%
from sim_utils import process_sim_results

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import numpy as np
import seaborn as sns
import pandas as pd
import session_info
import re
plt.rcParams['figure.dpi'] = 300
palette = ['#1f77b4', '#ff7f0e', '#2ca02c', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
session_info.show(html=False)
# Out:
# -----
# matplotlib          3.7.4
# numpy               1.22.3
# pandas              1.3.0
# seaborn             0.13.0
# session_info        1.0.0
# sim_utils           NA
# -----
# IPython             8.4.0
# jupyter_client      6.1.12
# jupyter_core        4.7.1
# notebook            6.4.4
# -----
# Python 3.8.5 (default, Sep  4 2020, 02:22:02) [Clang 10.0.0 ]
# macOS-10.16-x86_64-i386-64bit
# -----
# Session information updated at 2024-01-08 06:12

# %%
# Single-cell STARSolo simulation results

# Unique map

results_sim_vs_kallisto = process_sim_results("results/results_sim_vs_kallisto.txt")
results_sim_vs_offlist_kallisto = process_sim_results("results/results_sim_vs_offlist_kallisto.txt")
results_nac_sim_vs_kallisto = process_sim_results("results/results_nac_sim_vs_kallisto.txt")
results_nac_sim_vs_offlist_kallisto = process_sim_results("results/results_nac_sim_vs_offlist_kallisto.txt")

# Multimapping

results_sim_vs_kallisto_m = process_sim_results("results/results_sim_vs_kallisto_m.txt")
results_sim_vs_offlist_kallisto_m = process_sim_results("results/results_sim_vs_offlist_kallisto_m.txt")
results_nac_sim_vs_kallisto_m = process_sim_results("results/results_nac_sim_vs_kallisto_m.txt")
results_nac_sim_vs_offlist_kallisto_m = process_sim_results("results/results_nac_sim_vs_offlist_kallisto_m.txt")

# %%
# Single-cell STARSolo simulation results (mult)

# Unique map

results_mult_sim_vs_kallisto = process_sim_results("results/results_mult_sim_vs_kallisto.txt")
results_mult_sim_vs_offlist_kallisto = process_sim_results("results/results_mult_sim_vs_offlist_kallisto.txt")
results_nac_mult_sim_vs_kallisto = process_sim_results("results/results_nac_mult_sim_vs_kallisto.txt")
results_nac_mult_sim_vs_offlist_kallisto = process_sim_results(
    "results/results_nac_mult_sim_vs_offlist_kallisto.txt"
)

# Multimapping

results_mult_sim_vs_kallisto_m = process_sim_results("results/results_mult_sim_vs_kallisto_m.txt")
results_mult_sim_vs_offlist_kallisto_m = process_sim_results("results/results_mult_sim_vs_offlist_kallisto_m.txt")
results_nac_mult_sim_vs_kallisto_m = process_sim_results("results/results_nac_mult_sim_vs_kallisto_m.txt")
results_nac_mult_sim_vs_offlist_kallisto_m = process_sim_results(
    "results/results_nac_mult_sim_vs_offlist_kallisto_m.txt"
)

# %%
# Single-cell STARSolo simulation results (exon)

# Unique map

results_exon_sim_vs_kallisto = process_sim_results("results/results_exon_sim_vs_kallisto.txt")
results_exon_sim_vs_offlist_kallisto = process_sim_results("results/results_exon_sim_vs_offlist_kallisto.txt")
results_nac_exon_sim_vs_kallisto = process_sim_results("results/results_nac_exon_sim_vs_kallisto.txt")
results_nac_exon_sim_vs_offlist_kallisto = process_sim_results(
    "results/results_nac_exon_sim_vs_offlist_kallisto.txt"
)

# Multimapping

results_exon_sim_vs_kallisto_m = process_sim_results("results/results_exon_sim_vs_kallisto_m.txt")
results_exon_sim_vs_offlist_kallisto_m = process_sim_results("results/results_exon_sim_vs_offlist_kallisto_m.txt")
results_nac_exon_sim_vs_kallisto_m = process_sim_results("results/results_nac_exon_sim_vs_kallisto_m.txt")
results_nac_exon_sim_vs_offlist_kallisto_m = process_sim_results(
    "results/results_nac_exon_sim_vs_offlist_kallisto_m.txt"
)

# %%
# Overhangs


results_nac_sim_vs_offlistoverhang2_kallisto = process_sim_results(
    "results/results_nac_sim_vs_offlistoverhang2_kallisto.txt"
)
results_nac_sim_vs_offlistoverhang3_kallisto = process_sim_results(
    "results/results_nac_sim_vs_offlistoverhang3_kallisto.txt"
)
results_nac_sim_vs_offlistoverhang4_kallisto = process_sim_results(
    "results/results_nac_sim_vs_offlistoverhang4_kallisto.txt"
)
results_nac_sim_vs_offlistoverhang5_kallisto = process_sim_results(
    "results/results_nac_sim_vs_offlistoverhang5_kallisto.txt"
)
results_nac_sim_vs_offlistoverhang6_kallisto = process_sim_results(
    "results/results_nac_sim_vs_offlistoverhang6_kallisto.txt"
)
results_sim_vs_offlistoverhang2_kallisto = process_sim_results(
    "results/results_sim_vs_offlistoverhang2_kallisto.txt"
)
results_sim_vs_offlistoverhang3_kallisto = process_sim_results(
    "results/results_sim_vs_offlistoverhang3_kallisto.txt"
)
results_sim_vs_offlistoverhang4_kallisto = process_sim_results(
    "results/results_sim_vs_offlistoverhang4_kallisto.txt"
)
results_sim_vs_offlistoverhang5_kallisto = process_sim_results(
    "results/results_sim_vs_offlistoverhang5_kallisto.txt"
)
results_sim_vs_offlistoverhang6_kallisto = process_sim_results(
    "results/results_sim_vs_offlistoverhang6_kallisto.txt"
)

# %%
title = "Simulation: Single-cell RNA-seq (no multigene)"
w = results_sim_vs_kallisto["spearman_corrs"]
x = results_sim_vs_offlist_kallisto["spearman_corrs"]
y = results_nac_sim_vs_kallisto["spearman_corrs"]
z = results_nac_sim_vs_offlist_kallisto["spearman_corrs"]
data = np.concatenate([w, x, y, z])
labels = (
    ['kallisto [standard]'] * len(w) + 
    ['kallisto [standard] (D-list)'] * len(x) + 
    ['kallisto [nac]'] * len(y) + 
    ['kallisto [nac] (D-list)'] * len(z)
)

plot_height = 5  # height in inches
plot_aspect_ratio = 1.2 # width = plot_aspect_ratio * height
binwidth = 0.003
xlim_lower = 0.65


df = pd.DataFrame({'Value': data, 'Group': labels})
sns.set_theme()
sns.set_palette(palette)
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_style("whitegrid")
g = sns.displot(data=df, x="Value", hue="Group", fill=True, kde=True, 
                height=plot_height, aspect=plot_aspect_ratio, binwidth=binwidth, legend=False)

legend_labels = []
[legend_labels.append(x) for x in labels if x not in legend_labels]
unique_labels = pd.unique(df['Group'])
custom_patches = [mpatches.Patch(color=palette[i], label=label) for i, label in enumerate(unique_labels)]
plt.legend(handles=custom_patches, loc='upper left')
plt.xlim(xlim_lower, 1)
plt.title(title)
plt.xlabel('Per-cell Spearman coefficient')
plt.ylabel('Number of cells')
plt.show()

# %%
title = "Simulation: Single-cell RNA-seq (no multigene)"
w = results_sim_vs_kallisto_m["spearman_corrs"]
x = results_sim_vs_offlist_kallisto_m["spearman_corrs"]
y = results_nac_sim_vs_kallisto_m["spearman_corrs"]
z = results_nac_sim_vs_offlist_kallisto_m["spearman_corrs"]
data = np.concatenate([w, x, y, z])
labels = (
    ['kallisto (mult) [standard]'] * len(w) + 
    ['kallisto (mult) [standard] (D-list)'] * len(x) + 
    ['kallisto (mult) [nac]'] * len(y) + 
    ['kallisto (mult) [nac] (D-list)'] * len(z)
)

plot_height = 5  # height in inches
plot_aspect_ratio = 1.2 # width = plot_aspect_ratio * height
binwidth = 0.003
xlim_lower = 0.65


df = pd.DataFrame({'Value': data, 'Group': labels})
sns.set_theme()
sns.set_palette(palette)
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_style("whitegrid")
g = sns.displot(data=df, x="Value", hue="Group", fill=True, kde=True, 
                height=plot_height, aspect=plot_aspect_ratio, binwidth=binwidth, legend=False)

legend_labels = []
[legend_labels.append(x) for x in labels if x not in legend_labels]
unique_labels = pd.unique(df['Group'])
custom_patches = [mpatches.Patch(color=palette[i], label=label) for i, label in enumerate(unique_labels)]
plt.legend(handles=custom_patches, loc='upper left')
plt.xlim(xlim_lower, 1)
plt.title(title)
plt.xlabel('Per-cell Spearman coefficient')
plt.ylabel('Number of cells')
plt.show()

# %%
title = "Simulation: Single-cell RNA-seq (multigene)"
w = results_mult_sim_vs_kallisto["spearman_corrs"]
x = results_mult_sim_vs_offlist_kallisto["spearman_corrs"]
y = results_nac_mult_sim_vs_kallisto["spearman_corrs"]
z = results_nac_mult_sim_vs_offlist_kallisto["spearman_corrs"]
data = np.concatenate([w, x, y, z])
labels = (
    ['kallisto [standard]'] * len(w) + 
    ['kallisto [standard] (D-list)'] * len(x) + 
    ['kallisto [nac]'] * len(y) + 
    ['kallisto [nac] (D-list)'] * len(z)
)

plot_height = 5  # height in inches
plot_aspect_ratio = 1.2 # width = plot_aspect_ratio * height
binwidth = 0.003
xlim_lower = 0.65


df = pd.DataFrame({'Value': data, 'Group': labels})
sns.set_theme()
sns.set_palette(palette)
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_style("whitegrid")
g = sns.displot(data=df, x="Value", hue="Group", fill=True, kde=True, 
                height=plot_height, aspect=plot_aspect_ratio, binwidth=binwidth, legend=False)

legend_labels = []
[legend_labels.append(x) for x in labels if x not in legend_labels]
unique_labels = pd.unique(df['Group'])
custom_patches = [mpatches.Patch(color=palette[i], label=label) for i, label in enumerate(unique_labels)]
plt.legend(handles=custom_patches, loc='upper left')
plt.xlim(xlim_lower, 1)
plt.title(title)
plt.xlabel('Per-cell Spearman coefficient')
plt.ylabel('Number of cells')
plt.show()

# %%
title = "Simulation: Single-cell RNA-seq (multigene)"
w = results_mult_sim_vs_kallisto_m["spearman_corrs"]
x = results_mult_sim_vs_offlist_kallisto_m["spearman_corrs"]
y = results_nac_mult_sim_vs_kallisto_m["spearman_corrs"]
z = results_nac_mult_sim_vs_offlist_kallisto_m["spearman_corrs"]
data = np.concatenate([w, x, y, z])
labels = (
    ['kallisto (mult) [standard]'] * len(w) + 
    ['kallisto (mult) [standard] (D-list)'] * len(x) + 
    ['kallisto (mult) [nac]'] * len(y) + 
    ['kallisto (mult) [nac] (D-list)'] * len(z)
)

plot_height = 5  # height in inches
plot_aspect_ratio = 1.2 # width = plot_aspect_ratio * height
binwidth = 0.003
xlim_lower = 0.65


df = pd.DataFrame({'Value': data, 'Group': labels})
sns.set_theme()
sns.set_palette(palette)
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_style("whitegrid")
g = sns.displot(data=df, x="Value", hue="Group", fill=True, kde=True, height=plot_height, aspect=plot_aspect_ratio, binwidth=binwidth, legend=False)

legend_labels = []
[legend_labels.append(x) for x in labels if x not in legend_labels]
unique_labels = pd.unique(df['Group'])
custom_patches = [mpatches.Patch(color=palette[i], label=label) for i, label in enumerate(unique_labels)]
plt.legend(handles=custom_patches, loc='upper left')
plt.xlim(xlim_lower, 1)
plt.title(title)
plt.xlabel('Per-cell Spearman coefficient')
plt.ylabel('Number of cells')
plt.show()

# %%
title = "Simulation: Single-cell RNA-seq (exon-only; no multigene)"
w = results_exon_sim_vs_kallisto["spearman_corrs"]
x = results_exon_sim_vs_offlist_kallisto["spearman_corrs"]
y = results_nac_exon_sim_vs_kallisto["spearman_corrs"]
z = results_nac_exon_sim_vs_offlist_kallisto["spearman_corrs"]
data = np.concatenate([w, x, y, z])
labels = (
    ['kallisto [standard]'] * len(w) + 
    ['kallisto [standard] (D-list)'] * len(x) + 
    ['kallisto [nac]'] * len(y) + 
    ['kallisto [nac] (D-list)'] * len(z)
)

plot_height = 5  # height in inches
plot_aspect_ratio = 1.2 # width = plot_aspect_ratio * height
binwidth = 0.003
xlim_lower = 0.65


df = pd.DataFrame({'Value': data, 'Group': labels})
sns.set_theme()
sns.set_palette(palette)
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_style("whitegrid")
g = sns.displot(data=df, x="Value", hue="Group", fill=True, kde=True, height=plot_height, aspect=plot_aspect_ratio, binwidth=binwidth, legend=False)

legend_labels = []
[legend_labels.append(x) for x in labels if x not in legend_labels]
unique_labels = pd.unique(df['Group'])
custom_patches = [mpatches.Patch(color=palette[i], label=label) for i, label in enumerate(unique_labels)]
plt.legend(handles=custom_patches, loc='upper left')
plt.xlim(xlim_lower, 1)
plt.title(title)
plt.xlabel('Per-cell Spearman coefficient')
plt.ylabel('Number of cells')
plt.show()

# %%
title = "Simulation: Single-cell RNA-seq (exon-only; no multigene)"
w = results_exon_sim_vs_kallisto_m["spearman_corrs"]
x = results_exon_sim_vs_offlist_kallisto_m["spearman_corrs"]
y = results_nac_exon_sim_vs_kallisto_m["spearman_corrs"]
z = results_nac_exon_sim_vs_offlist_kallisto_m["spearman_corrs"]
data = np.concatenate([w, x, y, z])
labels = (
    ['kallisto (mult) [standard]'] * len(w) + 
    ['kallisto (mult) [standard] (D-list)'] * len(x) + 
    ['kallisto (mult) [nac]'] * len(y) + 
    ['kallisto (mult) [nac] (D-list)'] * len(z)
)

plot_height = 5  # height in inches
plot_aspect_ratio = 1.2 # width = plot_aspect_ratio * height
binwidth = 0.003
xlim_lower = 0.65


df = pd.DataFrame({'Value': data, 'Group': labels})
sns.set_theme()
sns.set_palette(palette)
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_style("whitegrid")
g = sns.displot(data=df, x="Value", hue="Group", fill=True, kde=True, 
                height=plot_height, aspect=plot_aspect_ratio, binwidth=binwidth, legend=False)

legend_labels = []
[legend_labels.append(x) for x in labels if x not in legend_labels]
unique_labels = pd.unique(df['Group'])
custom_patches = [mpatches.Patch(color=palette[i], label=label) for i, label in enumerate(unique_labels)]
plt.legend(handles=custom_patches, loc='upper left')
plt.xlim(xlim_lower, 1)
plt.title(title)
plt.xlabel('Per-cell Spearman coefficient')
plt.ylabel('Number of cells')
plt.show()

# %%
# !ls results/indices
# Out:
# nac_1.txt                       standard_1.txt
# nac_offlist_1.txt               standard_offlist_1.txt
# nac_offlistoverhang2_1.txt      standard_offlistoverhang2_1.txt
# nac_offlistoverhang3_1.txt      standard_offlistoverhang3_1.txt
# nac_offlistoverhang4_1.txt      standard_offlistoverhang4_1.txt
# nac_offlistoverhang5_1.txt      standard_offlistoverhang5_1.txt
# nac_offlistoverhang6_1.txt      standard_offlistoverhang6_1.txt

# %%
def extract_nkmers(file_name):

    # Read the content of the file
    with open(file_name, 'r') as file:
        file_content = file.read()

    # Regular expressions to find the numbers
    k_mers_pattern = r"\[index\] number of k-mers: ([\d,]+)"
    d_list_k_mers_pattern = r"\[index\] number of D-list k-mers: ([\d,]+)"

    # Search for the numbers in the file content
    k_mers_match = re.search(k_mers_pattern, file_content)
    d_list_k_mers_match = re.search(d_list_k_mers_pattern, file_content)

    # Extracting and converting the numbers
    k_mers = int(k_mers_match.group(1).replace(',', '')) if k_mers_match else 0
    d_list_k_mers = int(d_list_k_mers_match.group(1).replace(',', '')) if d_list_k_mers_match else 0
    
    # Subtract out the "dummy DFK" (one D-list k-mer is always added to the de Bruijn graph as a "dummy")
    if d_list_k_mers != 0:
        k_mers -= 1

    k_mers = "{:,}".format(k_mers)
    d_list_k_mers = "{:,}".format(d_list_k_mers)

    return [k_mers, d_list_k_mers]

# %%
nac_1 = extract_nkmers("results/indices/nac_1.txt")
nac_offlist_1 = extract_nkmers("results/indices/nac_offlist_1.txt")
nac_offlistoverhang2_1 = extract_nkmers("results/indices/nac_offlistoverhang2_1.txt")
nac_offlistoverhang3_1 = extract_nkmers("results/indices/nac_offlistoverhang3_1.txt")
nac_offlistoverhang4_1 = extract_nkmers("results/indices/nac_offlistoverhang4_1.txt")
nac_offlistoverhang5_1 = extract_nkmers("results/indices/nac_offlistoverhang5_1.txt")
nac_offlistoverhang6_1 = extract_nkmers("results/indices/nac_offlistoverhang6_1.txt")
standard_1 = extract_nkmers("results/indices/standard_1.txt")
standard_offlist_1 = extract_nkmers("results/indices/standard_offlist_1.txt")
standard_offlistoverhang2_1 = extract_nkmers("results/indices/standard_offlistoverhang2_1.txt")
standard_offlistoverhang3_1 = extract_nkmers("results/indices/standard_offlistoverhang3_1.txt")
standard_offlistoverhang4_1 = extract_nkmers("results/indices/standard_offlistoverhang4_1.txt")
standard_offlistoverhang5_1 = extract_nkmers("results/indices/standard_offlistoverhang5_1.txt")
standard_offlistoverhang6_1 = extract_nkmers("results/indices/standard_offlistoverhang6_1.txt")

# %%
index_df = pd.DataFrame({
    "Index type": [],  # Empty list for 'Index type' column
    "Number of k-mers": [],  # Empty list for 'Number of k-mers' column
    "Number of DFKs": [],  # Empty list for 'Number of DFKs' column
    "Overhang": []  # Empty list for 'Overhang' column
})
index_df.loc[len(index_df)] = ["standard"]+extract_nkmers("results/indices/standard_1.txt")+["0"]
index_df.loc[len(index_df)] = ["standard"]+extract_nkmers("results/indices/standard_offlist_1.txt")+["1"]
index_df.loc[len(index_df)] = ["standard"]+extract_nkmers("results/indices/standard_offlistoverhang2_1.txt")+["2"]
index_df.loc[len(index_df)] = ["standard"]+extract_nkmers("results/indices/standard_offlistoverhang3_1.txt")+["3"]
index_df.loc[len(index_df)] = ["standard"]+extract_nkmers("results/indices/standard_offlistoverhang4_1.txt")+["4"]
index_df.loc[len(index_df)] = ["standard"]+extract_nkmers("results/indices/standard_offlistoverhang5_1.txt")+["5"]
index_df.loc[len(index_df)] = ["standard"]+extract_nkmers("results/indices/standard_offlistoverhang6_1.txt")+["6"]
index_df.loc[len(index_df)] = ["nac"]+extract_nkmers("results/indices/nac_1.txt")+["0"]
index_df.loc[len(index_df)] = ["nac"]+extract_nkmers("results/indices/nac_offlist_1.txt")+["1"]
index_df.loc[len(index_df)] = ["nac"]+extract_nkmers("results/indices/nac_offlistoverhang2_1.txt")+["2"]
index_df.loc[len(index_df)] = ["nac"]+extract_nkmers("results/indices/nac_offlistoverhang3_1.txt")+["3"]
index_df.loc[len(index_df)] = ["nac"]+extract_nkmers("results/indices/nac_offlistoverhang4_1.txt")+["4"]
index_df.loc[len(index_df)] = ["nac"]+extract_nkmers("results/indices/nac_offlistoverhang5_1.txt")+["5"]
index_df.loc[len(index_df)] = ["nac"]+extract_nkmers("results/indices/nac_offlistoverhang6_1.txt")+["6"]

# %%
index_df
# Out:
#    Index type Number of k-mers Number of DFKs Overhang
# 0    standard      113,209,587              0        0
# 1    standard      113,209,587      4,333,316        1
# 2    standard      113,209,587      9,649,025        2
# 3    standard      113,209,587     15,696,903        3
# 4    standard      113,209,587     22,293,140        4
# 5    standard      113,209,587     29,278,838        5
# 6    standard      113,209,587     36,550,263        6
# 7         nac    1,398,470,117              0        0
# 8         nac    1,398,470,117     11,119,173        1
# 9         nac    1,398,470,117     21,338,179        2
# 10        nac    1,398,470,117     30,833,829        3
# 11        nac    1,398,470,117     39,760,674        4
# 12        nac    1,398,470,117     48,233,865        5
# 13        nac    1,398,470,117     56,344,346        6

# %%
index_df = pd.DataFrame({
    "Index type": [],  # Empty list for 'Index type' column
    "Number of k-mers": [],  # Empty list for 'Number of k-mers' column
    "Number of DFKs": [],  # Empty list for 'Number of DFKs' column
})
index_df.loc[len(index_df)] = ["standard"]+extract_nkmers("results/indices/standard_offlist_1.txt")
index_df.loc[len(index_df)] = ["nac"]+extract_nkmers("results/indices/nac_offlist_1.txt")

# %%
index_df
# Out:
#   Index type Number of k-mers Number of DFKs
# 0   standard      113,209,587      4,333,316
# 1        nac    1,398,470,117     11,119,173

# %%
def get_results(data_dict):

    results = data_dict.copy()
    results.pop('spearman_corrs', None)
    results.pop('spearman_corrs_zeroes_included', None)
    results.pop('errors', None)
    results.pop('false_positives', None)
    results.pop('false_negatives', None)
    results.pop('num_genes', None)
    results.pop('total_count', None)
    results.pop('num_barcodes_in_intersection', None)
    results.pop('num_barcodes_in_simulation', None)
    results.pop('num_barcodes_in_program', None)
    results.pop('num_genes_in_intersection', None)
    results.pop('num_genes_in_simulation', None)
    results.pop('num_genes_in_program', None)
    rmse = results['rmse']
    fnr = results['fnr']
    fpr = results['fpr']
    med_rho = results['median_spearman_corrs']
    med_rho_0 = results['median_pearson_corrs_zeroes_included']
    return [med_rho, med_rho_0, rmse, fpr, fnr]

# %%
results_df_template = pd.DataFrame({
    "Index type": [],
    "D-list": [],
    "mult": [],
    "Median ρ*": [],
    "Median r": [],
    "RMSE": [],
    "FPR": [],
    "FNR": [],
    "k-mers": [],
    "DFKs": [],
})

# %%
# Single-cell

results_df = results_df_template.copy()
results_df.loc[len(results_df)] = (
    ["standard", "", ""] +
    get_results(results_sim_vs_kallisto) + 
    extract_nkmers("results/indices/standard_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "✓", ""] + 
    get_results(results_sim_vs_offlist_kallisto) + 
    extract_nkmers("results/indices/standard_offlist_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "", ""] +
    get_results(results_nac_sim_vs_kallisto) + 
    extract_nkmers("results/indices/nac_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "✓", ""] + 
    get_results(results_nac_sim_vs_offlist_kallisto) + 
    extract_nkmers("results/indices/nac_offlist_1.txt"))
results_df
# Out:
#   Index type D-list mult  Median ρ*  Median r      RMSE       FPR       FNR  \
# 0   standard               0.742376  0.993061  0.626481  0.019403  0.000328
# 1   standard      ✓        0.973168  0.999815  0.081196  0.000808  0.000481
# 2        nac               0.959529  0.996173  0.484103  0.000646  0.000594
# 3        nac      ✓        0.980208  0.999809  0.084899  0.000206  0.000615
#
#           k-mers        DFKs
# 0    113,209,587           0
# 1    113,209,587   4,333,316
# 2  1,398,470,117           0
# 3  1,398,470,117  11,119,173

# %%
# Single-cell (mult enabled)

results_df = results_df_template.copy()
results_df.loc[len(results_df)] = (
    ["standard", "", "✓"] +
    get_results(results_sim_vs_kallisto_m) + 
    extract_nkmers("results/indices/standard_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "✓", "✓"] + 
    get_results(results_sim_vs_offlist_kallisto_m) + 
    extract_nkmers("results/indices/standard_offlist_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "", "✓"] +
    get_results(results_nac_sim_vs_kallisto_m) + 
    extract_nkmers("results/indices/nac_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "✓", "✓"] + 
    get_results(results_nac_sim_vs_offlist_kallisto_m) + 
    extract_nkmers("results/indices/nac_offlist_1.txt"))
results_df
# Out:
#   Index type D-list mult  Median ρ*  Median r      RMSE       FPR       FNR  \
# 0   standard           ✓   0.756161  0.992337  0.653089  0.050188  0.000241
# 1   standard      ✓    ✓   0.961758  0.999728  0.104715  0.002396  0.000431
# 2        nac           ✓   0.953292  0.995827  0.506452  0.023166  0.000517
# 3        nac      ✓    ✓   0.968557  0.999734  0.105673  0.018768  0.000542
#
#           k-mers        DFKs
# 0    113,209,587           0
# 1    113,209,587   4,333,316
# 2  1,398,470,117           0
# 3  1,398,470,117  11,119,173

# %%
# Single-cell (multi-gene; mult disabled)

results_df = results_df_template.copy()
results_df.loc[len(results_df)] = (
    ["standard", "", ""] +
    get_results(results_mult_sim_vs_kallisto) + 
    extract_nkmers("results/indices/standard_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "✓", ""] + 
    get_results(results_mult_sim_vs_offlist_kallisto) + 
    extract_nkmers("results/indices/standard_offlist_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "", ""] +
    get_results(results_nac_mult_sim_vs_kallisto) + 
    extract_nkmers("results/indices/nac_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "✓", ""] + 
    get_results(results_nac_mult_sim_vs_offlist_kallisto) + 
    extract_nkmers("results/indices/nac_offlist_1.txt"))
results_df
# Out:
#   Index type D-list mult  Median ρ*  Median r      RMSE       FPR       FNR  \
# 0   standard               0.679939  0.991087  0.682919  0.019123  0.002950
# 1   standard      ✓        0.896340  0.997867  0.287012  0.000783  0.003218
# 2        nac               0.883905  0.994031  0.555755  0.000626  0.003342
# 3        nac      ✓        0.902738  0.997835  0.289252  0.000197  0.003367
#
#           k-mers        DFKs
# 0    113,209,587           0
# 1    113,209,587   4,333,316
# 2  1,398,470,117           0
# 3  1,398,470,117  11,119,173

# %%
# Single-cell (multi-gene; mult enabled)

results_df = results_df_template.copy()
results_df.loc[len(results_df)] = (
    ["standard", "", "✓"] +
    get_results(results_mult_sim_vs_kallisto_m) + 
    extract_nkmers("results/indices/standard_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "✓", "✓"] + 
    get_results(results_mult_sim_vs_offlist_kallisto_m) + 
    extract_nkmers("results/indices/standard_offlist_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "", "✓"] +
    get_results(results_nac_mult_sim_vs_kallisto_m) + 
    extract_nkmers("results/indices/nac_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "✓", "✓"] + 
    get_results(results_nac_mult_sim_vs_offlist_kallisto_m) + 
    extract_nkmers("results/indices/nac_offlist_1.txt"))
results_df
# Out:
#   Index type D-list mult  Median ρ*  Median r      RMSE       FPR       FNR  \
# 0   standard           ✓   0.751159  0.991926  0.665475  0.051278  0.000265
# 1   standard      ✓    ✓   0.932976  0.999174  0.168532  0.004750  0.000480
# 2        nac           ✓   0.933767  0.995264  0.524677  0.037164  0.000568
# 3        nac      ✓    ✓   0.945177  0.999168  0.169827  0.032405  0.000595
#
#           k-mers        DFKs
# 0    113,209,587           0
# 1    113,209,587   4,333,316
# 2  1,398,470,117           0
# 3  1,398,470,117  11,119,173

# %%
# Single-cell (exon-only)

results_df = results_df_template.copy()
results_df.loc[len(results_df)] = (
    ["standard", "", ""] +
    get_results(results_exon_sim_vs_kallisto) + 
    extract_nkmers("results/indices/standard_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "✓", ""] + 
    get_results(results_exon_sim_vs_offlist_kallisto) + 
    extract_nkmers("results/indices/standard_offlist_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "", ""] +
    get_results(results_nac_exon_sim_vs_kallisto) + 
    extract_nkmers("results/indices/nac_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "✓", ""] + 
    get_results(results_nac_exon_sim_vs_offlist_kallisto) + 
    extract_nkmers("results/indices/nac_offlist_1.txt"))
results_df
# Out:
#   Index type D-list mult  Median ρ*  Median r      RMSE       FPR       FNR  \
# 0   standard               0.991464  0.999953  0.041320  0.000056  0.000367
# 1   standard      ✓        0.988987  0.999922  0.052084  0.000040  0.000487
# 2        nac               0.986443  0.999888  0.062731  0.000038  0.000595
# 3        nac      ✓        0.985968  0.999875  0.066492  0.000038  0.000615
#
#           k-mers        DFKs
# 0    113,209,587           0
# 1    113,209,587   4,333,316
# 2  1,398,470,117           0
# 3  1,398,470,117  11,119,173

# %%
# Single-cell (exon-only; mult enabled)

results_df = results_df_template.copy()
results_df.loc[len(results_df)] = (
    ["standard", "", "✓"] +
    get_results(results_exon_sim_vs_kallisto_m) + 
    extract_nkmers("results/indices/standard_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "✓", "✓"] + 
    get_results(results_exon_sim_vs_offlist_kallisto_m) + 
    extract_nkmers("results/indices/standard_offlist_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "", "✓"] +
    get_results(results_nac_exon_sim_vs_kallisto_m) + 
    extract_nkmers("results/indices/nac_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "✓", "✓"] + 
    get_results(results_nac_exon_sim_vs_offlist_kallisto_m) + 
    extract_nkmers("results/indices/nac_offlist_1.txt"))
results_df
# Out:
#   Index type D-list mult  Median ρ*  Median r      RMSE       FPR       FNR  \
# 0   standard           ✓   0.991460  0.999955  0.039947  0.000249  0.000321
# 1   standard      ✓    ✓   0.989052  0.999925  0.050895  0.000173  0.000448
# 2        nac           ✓   0.986388  0.999891  0.061643  0.000508  0.000554
# 3        nac      ✓    ✓   0.985920  0.999878  0.065441  0.000473  0.000575
#
#           k-mers        DFKs
# 0    113,209,587           0
# 1    113,209,587   4,333,316
# 2  1,398,470,117           0
# 3  1,398,470,117  11,119,173

# %%
results_df_template_overhang = pd.DataFrame({
    "Index type": [],
    "D-list overhang": [],
    "mult": [],
    "Median ρ*": [],
    "Median r": [],
    "RMSE": [],
    "FPR": [],
    "FNR": [],
    "k-mers": [],
    "DFKs": [],
})

# %%
# Single-cell

results_df = results_df_template_overhang.copy()
results_df.loc[len(results_df)] = (
    ["standard", "2", ""] +
    get_results(results_sim_vs_offlistoverhang2_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang2_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "3", ""] +
    get_results(results_sim_vs_offlistoverhang3_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang3_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "4", ""] +
    get_results(results_sim_vs_offlistoverhang4_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang4_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "5", ""] +
    get_results(results_sim_vs_offlistoverhang5_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang5_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "6", ""] +
    get_results(results_sim_vs_offlistoverhang6_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang6_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "2", ""] +
    get_results(results_nac_sim_vs_offlistoverhang2_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang2_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "3", ""] +
    get_results(results_nac_sim_vs_offlistoverhang3_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang3_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "4", ""] +
    get_results(results_nac_sim_vs_offlistoverhang4_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang4_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "5", ""] +
    get_results(results_nac_sim_vs_offlistoverhang5_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang5_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "6", ""] +
    get_results(results_nac_sim_vs_offlistoverhang6_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang6_1.txt")
)
results_df
# Out:
#   Index type D-list overhang mult  Median ρ*  Median r      RMSE       FPR  \
# 0   standard               2        0.973984  0.999819  0.080112  0.000739
# 1   standard               3        0.974748  0.999824  0.078881  0.000685
# 2   standard               4        0.975350  0.999826  0.078160  0.000643
# 3   standard               5        0.975842  0.999830  0.077472  0.000608
# 4   standard               6        0.976265  0.999833  0.076833  0.000580
# 5        nac               2        0.980336  0.999812  0.083905  0.000202
# 6        nac               3        0.980491  0.999814  0.082970  0.000197
# 7        nac               4        0.980585  0.999816  0.082474  0.000193
# 8        nac               5        0.980698  0.999817  0.082168  0.000189
# 9        nac               6        0.980771  0.999819  0.081806  0.000185
#
#         FNR         k-mers        DFKs
# 0  0.000495    113,209,587   9,649,025
# 1  0.000506    113,209,587  15,696,903
# ...

# %%
# Single-cell

results_df_template = pd.DataFrame({
    "Index type": [],
    "Overhang": [],
    "Median ρ*": [],
    "Median r": [],
    "RMSE": [],
    "FPR": [],
    "FNR": [],
    "k-mers": [],
    "DFKs": [],
})

results_df = results_df_template.copy()
results_df.loc[len(results_df)] = (
    ["standard", "0"] +
    get_results(results_sim_vs_kallisto) + 
    extract_nkmers("results/indices/standard_1.txt")
)
results_df.loc[len(results_df)] = (
    ["standard", "1"] + 
    get_results(results_sim_vs_offlist_kallisto) + 
    extract_nkmers("results/indices/standard_offlist_1.txt"))
results_df.loc[len(results_df)] = (
    ["standard", "2"] + 
    get_results(results_sim_vs_offlistoverhang2_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang2_1.txt"))
results_df.loc[len(results_df)] = (
    ["standard", "3"] + 
    get_results(results_sim_vs_offlistoverhang3_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang3_1.txt"))
results_df.loc[len(results_df)] = (
    ["standard", "4"] + 
    get_results(results_sim_vs_offlistoverhang4_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang4_1.txt"))
results_df.loc[len(results_df)] = (
    ["standard", "5"] + 
    get_results(results_sim_vs_offlistoverhang5_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang5_1.txt"))
results_df.loc[len(results_df)] = (
    ["standard", "6"] + 
    get_results(results_sim_vs_offlistoverhang6_kallisto) + 
    extract_nkmers("results/indices/standard_offlistoverhang6_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "0"] +
    get_results(results_nac_sim_vs_kallisto) + 
    extract_nkmers("results/indices/nac_1.txt")
)
results_df.loc[len(results_df)] = (
    ["nac", "1"] + 
    get_results(results_nac_sim_vs_offlist_kallisto) + 
    extract_nkmers("results/indices/nac_offlist_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "2"] + 
    get_results(results_nac_sim_vs_offlistoverhang2_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang2_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "3"] + 
    get_results(results_nac_sim_vs_offlistoverhang3_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang3_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "4"] + 
    get_results(results_nac_sim_vs_offlistoverhang4_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang4_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "5"] + 
    get_results(results_nac_sim_vs_offlistoverhang5_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang5_1.txt"))
results_df.loc[len(results_df)] = (
    ["nac", "6"] + 
    get_results(results_nac_sim_vs_offlistoverhang6_kallisto) + 
    extract_nkmers("results/indices/nac_offlistoverhang6_1.txt"))

# %%
plt.figure(figsize=(6, 8))

df_standard = results_df[results_df['Index type'] == 'standard']
df_nac = results_df[results_df['Index type'] == 'nac']

plt.plot(df_standard['Overhang'], df_standard['Median ρ*'],label='standard',
         marker='o',markersize=10,linewidth=3)
plt.plot(df_nac['Overhang'], df_nac['Median ρ*'], label='nac', marker='s', linewidth=3, 
         markersize=10,color=palette[2])

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Overhang', fontsize=20)
plt.ylabel('Median ρ*', fontsize=20)
plt.ylim(0.7, 1)
plt.grid(True)
plt.legend(fontsize=18)

plt.show()

# %%
plt.figure(figsize=(6, 8))

df_standard = results_df[results_df['Index type'] == 'standard']
df_nac = results_df[results_df['Index type'] == 'nac']

plt.plot(df_standard['Overhang'], df_standard['RMSE'], label='standard', marker='o', markersize=10, linewidth=3)
plt.plot(df_nac['Overhang'], df_nac['RMSE'], label='nac', marker='s', linewidth=3, markersize=10, color=palette[2])

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Overhang', fontsize=20)
plt.ylabel('RMSE', fontsize=20)
plt.ylim(0, 0.65)
plt.grid(True)
plt.legend(fontsize=18)

plt.show()

# %%
plt.figure(figsize=(6, 8))

df_standard = results_df[results_df['Index type'] == 'standard']
df_nac = results_df[results_df['Index type'] == 'nac']
df_standard.loc[:,'DFKs'] = df_standard.loc[:,'DFKs'].str.replace(',', '').astype(float) / 1000000
df_nac.loc[:,'DFKs'] = df_nac.loc[:,'DFKs'].str.replace(',', '').astype(float) / 1000000

plt.plot(df_standard['Overhang'], df_standard['DFKs'], label='standard', marker='o', markersize=10, linewidth=3)
plt.plot(df_nac['Overhang'], df_nac['DFKs'], label='nac', marker='s', linewidth=3, markersize=10, color=palette[2])

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Overhang', fontsize=20)
plt.ylabel('Number of DFKs (millions)', fontsize=20)
plt.grid(True)
plt.legend(fontsize=18)
plt.ticklabel_format(style='plain', axis='y')

plt.show()
# Out:
# /Users/dsull/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
